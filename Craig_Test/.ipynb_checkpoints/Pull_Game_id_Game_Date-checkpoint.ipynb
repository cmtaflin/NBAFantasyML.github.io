# %%
# Dependencies and Setup
import json
import pandas as pd
import requests

# %%
#Holding place potential csv file
#Bring in CSV into pandas dataframe
NBA_cityObject="NBAcities.csv"
NBA_cities_df=pd.read_csv(NBA_cityObject)

# %%
#Bring in data from internet as object then convert ot Json
schedule_response_obj=requests.get("http://data.nba.net/prod/v1/2018/schedule.json")
schedule_response=schedule_response_obj.json()

# %%
# Count # of Games
# schedule_response_count=schedule_response["league"]["standard"]
# schedule_count=len(schedule_response_count)
# schedule_count = 1

# %%
# If statement to exclude if tags = "pre-season"
# tags=schedule_response_list["tags"]

#Bring in elements for NBA Schedule
NBA_Schedule=[]
for item in schedule_response["league"]["standard"]:
    item_dict={}
    item_dict["gameID"]=item["gameId"]
    item_dict["startDateEastern"]=item["startDateEastern"]
    item_dict["hTeam"]=item["hTeam"]["teamId"]
    item_dict["vTeam"]=item["vTeam"]["teamId"]
    item_dict["national_broadcast"]=item["watch"]["broadcast"]["video"]["national"]["broadcasters"]
    

    # Create an Object list to store NBA Game Information
    NBA_Schedule.append(item_dict)

# %%
print(NBA_Schedule)
# Out:
# [{'gameID': '0011800001', 'startDateEastern': '20180928', 'hTeam': '1610612755', 'vTeam': '15016', 'national_broadcast': []}, {'gameID': '0011800002', 'startDateEastern': '20180928', 'hTeam': '1610612766', 'vTeam': '1610612738', 'national_broadcast': [{'shortName': 'NBA TV', 'longName': 'NBA TV'}]}, {'gameID': '0011800003', 'startDateEastern': '20180929', 'hTeam': '1610612761', 'vTeam': '1610612757', 'national_broadcast': []}, {'gameID': '0011800004', 'startDateEastern': '20180929', 'hTeam': '1610612742', 'vTeam': '15021', 'national_broadcast': []}, {'gameID': '0011800005', 'startDateEastern': '20180929', 'hTeam': '1610612744', 'vTeam': '1610612750', 'national_broadcast': [{'shortName': 'NBA TV', 'longName': 'NBA TV'}]}, {'gameID': '0011800006', 'startDateEastern': '20180929', 'hTeam': '1610612762', 'vTeam': '104', 'national_broadcast': []}, {'gameID': '0011800007', 'startDateEastern': '20180930', 'hTeam': '1610612759', 'vTeam': '1610612748', 'national_broadcast': [{'shortName': 'NBA TV', 'longName': 'NBA TV'}]}, {'gameID': '0011800008', 'startDateEastern': '20180930', 'hTeam': '1610612738', 'vTeam': '1610612766', 'national_broadcast': []}, {'gameID': '0011800009', 'startDateEastern': '20180930', 'hTeam': '1610612741', 'vTeam': '1610612740', 'national_broadcast': [{'shortName': 'NBA TV', 'longName': 'NBA TV'}]}, {'gameID': '0011800010', 'startDateEastern': '20180930', 'hTeam': '1610612747', 'vTeam': '1610612743', 'national_broadcast': [{'shortName': 'ESPN', 'longName': 'ESPN'}]}, {'gameID': '0011800011', 'startDateEastern': '20180930', 'hTeam': '1610612746', 'vTeam': '15015', 'national_broadcast': []}, {'gameID': '0011800012', 'startDateEastern': '20181001', 'hTeam': '1610612755', 'vTeam': '1610612753', 'national_broadcast': [{'shortName': 'NBA TV', 'longName': 'NBA TV'}]}, {'gameID': '0011800013', 'startDateEastern': '20181001', 'hTeam': '1610612764', 'vTeam': '1610612752', 'national_broadcast': []}, {'gameID': '0011800014', 'startDateEastern': '20181001', 'hTeam': '1610612737', 'vTeam': '1610612740', 'national_broadcast': []}, {'gameID': '0011800015', 'startDateEastern': '20181001', 'hTeam': '1610612756', 'vTeam': '1610612758', 'national_broadcast': []}, {'gameID': '0011800016', 'startDateEastern': '20181002', 'hTeam': '1610612766', 'vTeam': '1610612748', 'national_broadcast': []}, {'gameID': '0011800017', 'startDateEastern': '20181002', 'hTeam': '1610612738', 'vTeam': '1610612739', 'national_broadcast': [{'shortName': 'TNT', 'longName': 'Turner Networks'}]}, {'gameID': '0011800018', 'startDateEastern': '20181002', 'hTeam': '1610612745', 'vTeam': '1610612763', 'national_broadcast': []}, {'gameID': '0011800019', 'startDateEastern': '20181002', 'hTeam': '1610612762', 'vTeam': '1610612761', 'national_broadcast': []}, {'gameID': '0011800020', 'startDateEastern': '20181002', 'hTeam': '1610612747', 'vTeam': '1610612743', 'national_broadcast': [{'shortName': 'TNT', 'longName': 'Turner Networks'}]}, {'gameID': '0011800021', 'startDateEastern': '20181003', 'hTeam': '1610612751', 'vTeam': '1610612752', 'national_broadcast': []}, {'gameID': '0011800022', 'startDateEastern': '20181003', 'hTeam': '1610612749', 'vTeam': '1610612741', 'national_broadcast': [{'shortName': 'NBA TV', 'longName': 'NBA TV'}]}, {'gameID': '0011800023', 'startDateEastern': '20181003', 'hTeam': '1610612760', 'vTeam': '1610612765', 'national_broadcast': []}, {'gameID': '0011800024', 'startDateEastern': '20181003', 'hTeam': '1610612756', 'vTeam': '15020', 'national_broadcast': []}, {'gameID': '0011800025', 'startDateEastern': '20181003', 'hTeam': '1610612746', 'vTeam': '1610612750', 'national_broadcast': [{'shortName': 'NBA TV', 'longName': 'NBA TV'}]}, {'gameID': '0011800026', 'startDateEastern': '20181004', 'hTeam': '1610612745', 'vTeam': '1610612754', 'national_broadcast': [{'shortName': 'NBA TV', 'longName': 'NBA TV'}]}, {'gameID': '0011800027', 'startDateEastern': '20181004', 'hTeam': '1610612747', 'vTeam': '1610612758', 'national_broadcast': [{'shortName': 'NB ...
