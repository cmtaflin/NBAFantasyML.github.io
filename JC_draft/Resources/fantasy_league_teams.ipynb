# %%
# Dependencies
import pandas as pd
import json
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy import Column, Integer, String, Float, Date
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine, inspect, func, distinct
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import sqlite3
from sqlite3 import Error

# %%
fantasy_league = pd.read_csv("League_Test.csv")
fantasy_league.head()
# Out:
#    Fantasy_Team_ID    Fantasy_Team_Name        Player_Name Positions  \
# 0       7110302001  GOOD D-WILL HUNTING  LAMARCUS ALDRIDGE      PF,C
# 1       7110302001  GOOD D-WILL HUNTING      DEMAR DEROZAN     SG,SF
# 2       7110302001  GOOD D-WILL HUNTING  SPENCER DINWIDDIE        PG
# 3       7110302001  GOOD D-WILL HUNTING      EVAN FOURNIER     SG,SF
# 4       7110302001  GOOD D-WILL HUNTING        RUDY GOBERT         C
#
#    personid      teamid  Guard  Forward  Center
# 0    200746  1610612759      0        1       1
# 1    201942  1610612759      1        1       0
# 2    203915  1610612751      1        0       0
# 3    203095  1610612753      1        1       0
# 4    203497  1610612762      0        0       1

# %%
engine = create_engine("sqlite:///db/NBA_Data.sqlite")
conn = engine.connect()

engine.table_names()

fantasy_league.set_index("personid", inplace=True)

#Load Players_Info table
fantasy_league.to_sql('fantasy_league',conn, if_exists='replace', index=True)

# %%
pd.read_sql('select * from fantasy_league', conn)
# Out:
#      personid  Fantasy_Team_ID     Fantasy_Team_Name         Player_Name  \
# 0      200746       7110302001   GOOD D-WILL HUNTING   LAMARCUS ALDRIDGE
# 1      201942       7110302001   GOOD D-WILL HUNTING       DEMAR DEROZAN
# 2      203915       7110302001   GOOD D-WILL HUNTING   SPENCER DINWIDDIE
# 3      203095       7110302001   GOOD D-WILL HUNTING       EVAN FOURNIER
# 4      203497       7110302001   GOOD D-WILL HUNTING         RUDY GOBERT
# 5      201935       7110302001   GOOD D-WILL HUNTING        JAMES HARDEN
# 6      203897       7110302001   GOOD D-WILL HUNTING         ZACH LAVINE
# 7     1628374       7110302001   GOOD D-WILL HUNTING     LAURI MARKKANEN
# 8      202703       7110302001   GOOD D-WILL HUNTING      NIKOLA MIROTIC
# 9      201937       7110302001   GOOD D-WILL HUNTING         RICKY RUBIO
# 10     202684       7110302001   GOOD D-WILL HUNTING    TRISTAN THOMPSON
# 11    1626167       7110302001   GOOD D-WILL HUNTING        MYLES TURNER
# ...
